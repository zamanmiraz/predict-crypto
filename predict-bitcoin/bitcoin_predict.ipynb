# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load dataset
df = pd.read_csv(r'.\Dataset\btcusd_1-min_data.csv')

# %%
pd.to_datetime(1325412060.0, unit='s')
# Out:
# Timestamp('2012-01-01 10:01:00')

# %%
# Which date has the highest closing price?
highest_close_date = df.loc[df['Close'].idxmax(), 'Timestamp']
highest_close_date = pd.to_datetime(highest_close_date, unit='s').date()
print(f"The date with the highest closing price is: {highest_close_date}")
# Out:
# The date with the highest closing price is: 2025-07-14

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
df.set_index('Timestamp', inplace=True)
df = df.sort_index()
df.tail()
# Out:
#                          Open      High       Low     Close    Volume
# Timestamp
# 2025-07-16 00:46:00  117899.0  117942.0  117899.0  117941.0  0.056977
# 2025-07-16 00:47:00  117928.0  118071.0  117928.0  118048.0  3.990983
# 2025-07-16 00:48:00  118071.0  118080.0  118030.0  118080.0  0.411239
# 2025-07-16 00:49:00  118085.0  118156.0  118085.0  118129.0  2.650265
# 2025-07-16 00:50:00  118128.0  118130.0  118060.0  118124.0  0.284409
